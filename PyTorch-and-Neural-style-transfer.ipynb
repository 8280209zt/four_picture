# %%
import torch
import torchvision
from torchvision import transforms, models
from PIL import Image
import matplotlib.pyplot as plt
from torch.autograd import Variable
import copy
import cv2
import numpy as np

# %matplotlib inline

# %% [markdown]
# 图片读取

# %%
transform = transforms.Compose([transforms.Resize([224,224]),
                               transforms.ToTensor()])

def  loadimg(path = None):
    img = Image.open(path)
    img = transform(img)
    img = img.unsqueeze(0)
    return img
    
ToPIL = torchvision.transforms.ToPILImage()
    
def img_show(img, title = None):
    img = img.clone().cpu()
    img = img.view(3,224,224)
    img = ToPIL(img)

    if title is not None:
        plt.title(title)
    plt.imshow(img)

# %% [markdown]
# 4通道变3通道（四通道图像是在三通道的基础上加上了一个Alpha通道）

# %%
src = cv2.imread('37.jpg',cv2.IMREAD_COLOR)
cv2.imwrite('37.jpg',src)
 
#最后再读取change.png这张图片
img1 = Image.open('37.jpg')
img1 = np.array(img1)
print(img1.shape)

# from PIL import Image
# image = Image.open(filename).convert('RGB')
# rows,cols,channels=img.shape
# 这行代码的意思是把图片中像素的行数，列数以及图像通道数返回给rows，cols，channels
# Out:
# (287, 310, 3)

# %%
content_img = loadimg("1234.jpg")
content_img = Variable(content_img).cuda()
style_img = loadimg("3.jpg")
style_img = Variable(style_img).cuda()

# %%
print(style_img.size())
# Out:
# torch.Size([1, 3, 224, 224])

# %% [markdown]
# 图片显示

# %%
plt.figure()
img_show(content_img.data, title = "Content_Image")
plt.figure()
img_show(style_img.data, title = "Style_Image")

# %% [markdown]
# 定义内容Loss,风格Loss和Gram矩阵

# %%
class Content_loss(torch.nn.Module):
    def __init__(self, weight, target):
        super(Content_loss, self).__init__()
        self.weight = weight
        self.target = target.detach()*weight
        self.loss_fn = torch.nn.MSELoss()
        
    def forward(self, input):
        self.loss = self.loss_fn(input*self.weight, self.target)
        self.output = input
        return self.output
        
    def backward(self):
        self.loss.backward(retain_graph = True)
        return self.loss

# %%
class gram_matrix(torch.nn.Module):
    def forward(self, input):
        a,b,c,d = input.size()
        feature = input.view(a*b, c*d)
        gram = torch.mm(feature, feature.t())
        return gram.div(a*b*c*d)

# %%
class Style_loss(torch.nn.Module):
    def __init__(self, weight, target):
        super(Style_loss, self).__init__()
        self.weight = weight
        self.target = target.detach()*weight
        self.loss_fn = torch.nn.MSELoss()
        self.gram = gram_matrix()
        
    def forward(self, input):
        self.output = input.clone()
        self.G = self.gram(input)
        self.G.mul_(self.weight)
        self.loss = self.loss_fn(self.G, self.target)
        return self.output
    def backward(self):
        self.loss.backward(retain_graph = True)
        return self.loss

# %% [markdown]
# 定义需要优化的参数

# %% [markdown]
# 迁移模型

# %%
use_gpu = torch.cuda.is_available()
cnn = models.vgg16(pretrained=True).features
if use_gpu:
    cnn = cnn.cuda()

# %%
print(cnn)
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU(inplace=True)
#   (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU(inplace=True)
#   (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (6): ReLU(inplace=True)
#   (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (8): ReLU(inplace=True)
#   (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(inplace=True)
#   (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (13): ReLU(inplace=True)
#   (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (15): ReLU(inplace=True)
#   (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (18): ReLU(inplace=True)
#   (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (20): ReLU(inplace=True)
#   (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (22): ReLU(inplace=True)
#   (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (25): ReLU(inplace=True)
#   (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (27): ReLU(inplace=True)
#   (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (29): ReLU(inplace=True)
#   (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )

# %% [markdown]
# 构造自己的神经网络

# %%
content_layer = ["Conv_5","Conv_6"]

style_layer = ["Conv_1", "Conv_2", "Conv_3", "Conv_4", "Conv_5"]



content_losses = []
style_losses = []

conten_weight = 1
style_weight = 1000

new_model = torch.nn.Sequential()

model = copy.deepcopy(cnn)

gram = gram_matrix()

if use_gpu:
    new_model = new_model.cuda()
    gram = gram.cuda()

index = 1
for layer in list(model):
    if isinstance(layer, torch.nn.Conv2d):
        name = "Conv_"+str(index)
        new_model.add_module(name, layer)
        if name in content_layer:
            target = new_model(content_img).clone()
            content_loss = Content_loss(conten_weight, target)
            new_model.add_module("content_loss_"+str(index), content_loss)
            content_losses.append(content_loss)
            
        if name in style_layer:
            target = new_model(style_img).clone()
            target = gram(target)
            style_loss = Style_loss(style_weight, target)
            new_model.add_module("style_loss_"+str(index), style_loss)
            style_losses.append(style_loss)
            
    if isinstance(layer, torch.nn.ReLU):
        name = "Relu_"+str(index)
        new_model.add_module(name, layer)
        index = index+1
            
    if isinstance(layer, torch.nn.MaxPool2d):
        name = "MaxPool_"+str(index)
        new_model.add_module(name, layer)

print(new_model)
# Out:
# Sequential(
#   (Conv_1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (style_loss_1): Style_loss(
#     (loss_fn): MSELoss()
#     (gram): gram_matrix()
#   )
#   (Relu_1): ReLU(inplace=True)
#   (Conv_2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (style_loss_2): Style_loss(
#     (loss_fn): MSELoss()
#     (gram): gram_matrix()
#   )
#   (Relu_2): ReLU(inplace=True)
#   (MaxPool_3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Conv_3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (style_loss_3): Style_loss(
#     (loss_fn): MSELoss()
#     (gram): gram_matrix()
#   )
#   (Relu_3): ReLU(inplace=True)
#   (Conv_4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (style_loss_4): Style_loss(
#     (loss_fn): MSELoss()
#     (gram): gram_matrix()
#   )
#   (Relu_4): ReLU(inplace=True)
#   (MaxPool_5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Conv_5): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (content_loss_5): Content_loss(
#     (loss_fn): MSELoss()
#   )
#   (style_loss_5): Style_loss(
#     (loss_fn): MSELoss()
#     (gram): gram_matrix()
#   )
#   (Relu_5): ReLU(inplace=True)
#   (Conv_6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (content_loss_6): Content_loss(
#     (loss_fn): MSELoss()
#   )
#   (Relu_6): ReLU(inplace=True)
#   (Conv_7): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (Relu_7): ReLU(inplace=True)
#   (MaxPool_8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Conv_8): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (Relu_8): ReLU(inplace=True)
#   (Conv_9): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (Relu_9): ReLU(inplace=True)
#   (Conv_10): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (Relu_10): ReLU(inplace=True)
#   (MaxPool_11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Conv_11): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (Relu_11): ReLU(inplace=True)
#   (Conv_12): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (Relu_12): ReLU(inplace=True)
#   (Conv_13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (Relu_13): ReLU(inplace=True)
#   (MaxPool_14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )

# %%
input_img = content_img.clone()

parameter = torch.nn.Parameter(input_img.data)
optimizer = torch.optim.LBFGS([parameter])

# %%
n_epoch = 100

run = [0]
while run[0] <= n_epoch:
    def closure():
        optimizer.zero_grad()
        style_score = 0
        content_score = 0
        parameter.data.clamp_(0,1)
        new_model(parameter)
        for sl in style_losses:
            style_score += sl.backward()
        
        for cl in content_losses:
            content_score += cl.backward()
        
        run[0] += 1 
        if run[0] % 50 == 0:
            print('{} Style Loss : {:4f} Content Loss: {:4f}'.format(run[0],
                 style_score.item(), content_score.item())) 

        return style_score+content_score
    optimizer.step(closure)
# Out:
# 50 Style Loss : 8.466866 Content Loss: 11.636766
# 100 Style Loss : 5.451098 Content Loss: 11.156473

# %%
parameter.data.clamp_(0,1)
plt.figure()
img_show(parameter.data, title="Output Image")

# %% [markdown]
# # 全部代码

# %%
import torch
import torchvision
from torchvision import transforms, models
from PIL import Image
import matplotlib.pyplot as plt
from torch.autograd import Variable
import copy
import cv2
import numpy as np

# %matplotlib inline

transform = transforms.Compose([transforms.Resize([224,224]),
                               transforms.ToTensor()])

def  loadimg(path = None):
    img = Image.open(path)
    img = transform(img)
    img = img.unsqueeze(0)
    return img
    
ToPIL = torchvision.transforms.ToPILImage()
    
def img_show(img, title = None):
    img = img.clone().cpu()
    img = img.view(3,224,224)
    img = ToPIL(img)

    if title is not None:
        plt.title(title)
    plt.imshow(img)

content_img = loadimg("2222.jpg")
content_img = Variable(content_img).cuda()
style_img = loadimg("37.jpg")
style_img = Variable(style_img).cuda()

plt.figure()
img_show(content_img.data, title = "Content_Image")
plt.figure()
img_show(style_img.data, title = "Style_Image")

class Content_loss(torch.nn.Module):
    def __init__(self, weight, target):
        super(Content_loss, self).__init__()
        self.weight = weight
        self.target = target.detach()*weight
        self.loss_fn = torch.nn.MSELoss()
        
    def forward(self, input):
        self.loss = self.loss_fn(input*self.weight, self.target)
        self.output = input
        return self.output
        
    def backward(self):
        self.loss.backward(retain_graph = True)
        return self.loss
        
class gram_matrix(torch.nn.Module):
    def forward(self, input):
        a,b,c,d = input.size()
        feature = input.view(a*b, c*d)
        gram = torch.mm(feature, feature.t())
        return gram.div(a*b*c*d)
        
class Style_loss(torch.nn.Module):
    def __init__(self, weight, target):
        super(Style_loss, self).__init__()
        self.weight = weight
        self.target = target.detach()*weight
        self.loss_fn = torch.nn.MSELoss()
        self.gram = gram_matrix()
        
    def forward(self, input):
        self.output = input.clone()
        self.G = self.gram(input)
        self.G.mul_(self.weight)
        self.loss = self.loss_fn(self.G, self.target)
        return self.output
    def backward(self):
        self.loss.backward(retain_graph = True)
        return self.loss

use_gpu = torch.cuda.is_available()
cnn = models.vgg16(pretrained=True).features
if use_gpu:
    cnn = cnn.cuda()
    
content_layer = ["Conv_4","Conv_6","Conv_7"]

style_layer = ["Conv_1", "Conv_2", "Conv_3", "Conv_4"]





content_losses = []
style_losses = []

conten_weight = 1
style_weight = 1000

new_model = torch.nn.Sequential()

model = copy.deepcopy(cnn)

gram = gram_matrix()

if use_gpu:
    new_model = new_model.cuda()
    gram = gram.cuda()

index = 1
for layer in list(model):
    if isinstance(layer, torch.nn.Conv2d):
        name = "Conv_"+str(index)
        new_model.add_module(name, layer)
        if name in content_layer:
            target = new_model(content_img).clone()
            content_loss = Content_loss(conten_weight, target)
            new_model.add_module("content_loss_"+str(index), content_loss)
            content_losses.append(content_loss)
            
        if name in style_layer:
            target = new_model(style_img).clone()
            target = gram(target)
            style_loss = Style_loss(style_weight, target)
            new_model.add_module("style_loss_"+str(index), style_loss)
            style_losses.append(style_loss)
            
    if isinstance(layer, torch.nn.ReLU):
        name = "Relu_"+str(index)
        new_model.add_module(name, layer)
        index = index+1
            
    if isinstance(layer, torch.nn.MaxPool2d):
        name = "MaxPool_"+str(index)
        new_model.add_module(name, layer)

input_img = content_img.clone()

parameter = torch.nn.Parameter(input_img.data)
optimizer = torch.optim.LBFGS([parameter])

n_epoch = 300

run = [0]
while run[0] <= n_epoch:
    def closure():
        optimizer.zero_grad()
        style_score = 0
        content_score = 0
        parameter.data.clamp_(0,1)
        new_model(parameter)
        for sl in style_losses:
            style_score += sl.backward()
        
        for cl in content_losses:
            content_score += cl.backward()
        
        run[0] += 1 
        if run[0] % 50 == 0:
            print('{} Style Loss : {:4f} Content Loss: {:4f}'.format(run[0],
                 style_score.item(), content_score.item())) 

        return style_score+content_score
    optimizer.step(closure)
    
parameter.data.clamp_(0,1)
plt.figure()
img_show(parameter.data, title="Output Image")
# Out:
# 50 Style Loss : 4.743806 Content Loss: 3.668330
# 100 Style Loss : 2.092923 Content Loss: 4.363611
# 150 Style Loss : 547.376404 Content Loss: 72.384933
# 200 Style Loss : 97.106110 Content Loss: 43.136482
# 250 Style Loss : 127.983475 Content Loss: 54.780949
# 300 Style Loss :  inf Content Loss: 41.609879
# 350 Style Loss :  inf Content Loss: 41.609879
# 400 Style Loss :  inf Content Loss: 41.609879
# 450 Style Loss :  inf Content Loss: 41.609879
# 500 Style Loss :  inf Content Loss: 41.609879
# 550 Style Loss :  inf Content Loss: 41.609879
# 600 Style Loss :  inf Content Loss: 41.609879
# 650 Style Loss :  inf Content Loss: 41.609879
# 700 Style Loss :  inf Content Loss: 41.609879
# 750 Style Loss :  inf Content Loss: 41.609879
# 800 Style Loss :  inf Content Loss: 41.609879
# 850 Style Loss :  inf Content Loss: 41.609879
# 900 Style Loss :  inf Content Loss: 41.609879
# 950 Style Loss :  inf Content Loss: 41.609879
# 1000 Style Loss :  inf Content Loss: 41.609879
# 1050 Style Loss :  inf Content Loss: 41.609879
# 1100 Style Loss :  inf Content Loss: 41.609879
# 1150 Style Loss :  inf Content Loss: 41.609879
# 1200 Style Loss :  inf Content Loss: 41.609879
# 1250 Style Loss :  inf Content Loss: 41.609879
# 1300 Style Loss :  inf Content Loss: 41.609879
# 1350 Style Loss :  inf Content Loss: 41.609879
# 1400 Style Loss :  inf Content Loss: 41.609879
# 1450 Style Loss :  inf Content Loss: 41.609879
# 1500 Style Loss :  inf Content Loss: 41.609879
# 1550 Style Loss :  inf Content Loss: 41.609879
# 1600 Style Loss :  inf Content Loss: 41.609879
# 1650 Style Loss :  inf Content Loss: 41.609879
# 1700 Style Loss :  inf Content Loss: 41.609879
# 1750 Style Loss :  inf Content Loss: 41.609879
# 1800 Style Loss :  inf Content Loss: 41.609879
# 1850 Style Loss :  inf Content Loss: 41.609879
# 1900 Style Loss :  inf Content Loss: 41.609879
# 1950 Style Loss :  inf Content Loss: 41.609879
# 2000 Style Loss :  inf Content Loss: 41.609879
# 2050 Style Loss :  inf Content Loss: 41.609879
# 2100 Style Loss :  inf Content Loss: 41.609879
# 2150 Style Loss :  inf Content Loss: 41.609879
# 2200 Style Loss :  inf Content Loss: 41.609879
# 2250 Style Loss :  inf Content Loss: 41.609879
# 2300 Style Loss :  inf Content Loss: 41.609879
# 2350 Style Loss :  inf Content Loss: 41.609879
# 2400 Style Loss :  inf Content Loss: 41.609879
# 2450 Style Loss :  inf Content Loss: 41.609879
# 2500 Style Loss :  inf Content Loss: 41.609879
# 2550 Style Loss :  inf Content Loss: 41.609879
# 2600 Style Loss :  inf Content Loss: 41.609879
# 2650 Style Loss :  inf Content Loss: 41.609879
# 2700 Style Loss :  inf Content Loss: 41.609879
# 2750 Style Loss :  inf Content Loss: 41.609879
# 2800 Style Loss :  inf Content Loss: 41.609879
# 2850 Style Loss :  inf Content Loss: 41.609879
# 2900 Style Loss :  inf Content Loss: 41.609879
# 2950 Style Loss :  inf Content Loss: 41.609879
# 3000 Style Loss :  inf Content Loss: 41.609879
# 3050 Style Loss :  inf Content Loss: 41.609879
# 3100 Style Loss :  inf Content Loss: 41.609879
# 3150 Style Loss :  inf Content Loss: 41.609879
# 3200 Style Loss :  inf Content Loss: 41.609879
# 3250 Style Loss :  inf Content Loss: 41.609879
# 3300 Style Loss :  inf Content Loss: 41.609879
# 3350 Style Loss :  inf Content Loss: 41.609879
# 3400 Style Loss :  inf Content Loss: 41.609879
# 3450 Style Loss :  inf Content Loss: 41.609879
# 3500 Style Loss :  inf Content Loss: 41.609879
# 3550 Style Loss :  inf Content Loss: 41.609879
# 3600 Style Loss :  inf Content Loss: 41.609879
# 3650 Style Loss :  inf Content Loss: 41.609879
# 3700 Style Loss :  inf Content Loss: 41.609879
# 3750 Style Loss :  inf Content Loss: 41.609879
# 3800 Style Loss :  inf Content Loss: 41.609879
# 3850 Style Loss :  inf Content Loss: 41.609879
# 3900 Style Loss :  inf Content Loss: 41.609879
# 3950 Style Loss :  inf Content Loss: 41.609879
# 4000 Style Loss :  inf Content Loss: 41.609879
# 4050 Style Loss :  inf Content Loss: 41.609879
# 4100 Style Loss :  inf Content Loss: 41.609879
# 4150 Style Loss :  inf Content Loss: 41.609879
# 4200 Style Loss :  inf Content Loss: 41.609879
# 4250 Style Loss :  inf Content Loss: 41.609879
# 4300 Style Loss :  inf Content Loss: 41.609879
# 4350 Style Loss :  inf Content Loss: 41.609879
# 4400 Style Loss :  inf Content Loss: 41.609879
# 4450 Style Loss :  inf Content Loss: 41.609879
# 4500 Style Loss :  inf Content Loss: 41.609879
# 4550 Style Loss :  inf Content Loss: 41.609879
# 4600 Style Loss :  inf Content Loss: 41.609879
# 4650 Style Loss :  inf Content Loss: 41.609879
# 4700 Style Loss :  inf Content Loss: 41.609879
# 4750 Style Loss :  inf Content Loss: 41.609879
# 4800 Style Loss :  inf Content Loss: 41.609879
# 4850 Style Loss :  inf Content Loss: 41.609879
# 4900 Style Loss :  inf Content Loss: 41.609879
# 4950 Style Loss :  inf Content Loss: 41.609879
# 5000 Style Loss :  inf Content Loss: 41.609879
# 5050 Style Loss :  inf Content Loss: 41.609879
# 5100 Style Loss :  inf Content Loss: 41.609879
# 5150 Style Loss :  inf Content Loss: 41.609879
# 5200 Style Loss :  inf Content Loss: 41.609879
# 5250 Style Loss :  inf Content Loss: 41.609879
# 5300 Style Loss :  inf Content Loss: 41.609879
# 5350 Style Loss :  inf Content Loss: 41.609879
# 5400 Style Loss :  inf Content Loss: 41.609879
# 5450 Style Loss :  inf Content Loss: 41.609879
# 5500 Style Loss :  inf Content Loss: 41.609879
# 5550 Style Loss :  inf Content Loss: 41.609879
# 5600 Style Loss :  inf Content Loss: 41.609879
# 5650 Style Loss :  inf Content Loss: 41.609879
# 5700 Style Loss :  inf Content Loss: 41.609879
# 5750 Style Loss :  inf Content Loss: 41.609879
# 5800 Style Loss :  inf Content Loss: 41.609879
# 5850 Style Loss :  inf Content Loss: 41.609879
# 5900 Style Loss :  inf Content Loss: 41.609879
# 5950 Style Loss :  inf Content Loss: 41.609879
# 6000 Style Loss :  inf Content Loss: 41.609879
# 6050 Style Loss :  inf Content Loss: 41.609879
# 6100 Style Loss :  inf Content Loss: 41.609879
# 6150 Style Loss :  inf Content Loss: 41.609879
# 6200 Style Loss :  inf Content Loss: 41.609879
# 6250 Style Loss :  inf Content Loss: 41.609879
# 6300 Style Loss :  inf Content Loss: 41.609879
# 6350 Style Loss :  inf Content Loss: 41.609879
# 6400 Style Loss :  inf Content Loss: 41.609879
# 6450 Style Loss :  inf Content Loss: 41.609879
# 6500 Style Loss :  inf Content Loss: 41.609879
# 6550 Style Loss :  inf Content Loss: 41.609879
# 6600 Style Loss :  inf Content Loss: 41.609879
# 6650 Style Loss :  inf Content Loss: 41.609879
# 6700 Style Loss :  inf Content Loss: 41.609879
# 6750 Style Loss :  inf Content Loss: 41.609879
# 6800 Style Loss :  inf Content Loss: 41.609879
# 6850 Style Loss :  inf Content Loss: 41.609879
# 6900 Style Loss :  inf Content Loss: 41.609879
# 6950 Style Loss :  inf Content Loss: 41.609879
# 7000 Style Loss :  inf Content Loss: 41.609879
# 7050 Style Loss :  inf Content Loss: 41.609879
# 7100 Style Loss :  inf Content Loss: 41.609879
# 7150 Style Loss :  inf Content Loss: 41.609879
# 7200 Style Loss :  inf Content Loss: 41.609879
# 7250 Style Loss :  inf Content Loss: 41.609879
# 7300 Style Loss :  inf Content Loss: 41.609879
# 7350 Style Loss :  inf Content Loss: 41.609879
# 7400 Style Loss :  inf Content Loss: 41.609879
# 7450 Style Loss :  inf Content Loss: 41.609879
# 7500 Style Loss :  inf Content Loss: 41.609879
# 7550 Style Loss :  inf Content Loss: 41.609879
# 7600 Style Loss :  inf Content Loss: 41.609879
# 7650 Style Loss :  inf Content Loss: 41.609879
# 7700 Style Loss :  inf Content Loss: 41.609879
# 7750 Style Loss :  inf Content Loss: 41.609879
# 7800 Style Loss :  inf Content Loss: 41.609879
# 7850 Style Loss :  inf Content Loss: 41.609879
# 7900 Style Loss :  inf Content Loss: 41.609879
# 7950 Style Loss :  inf Content Loss: 41.609879
# 8000 Style Loss :  inf Content Loss: 41.609879
# 8050 Style Loss :  inf Content Loss: 41.609879
# 8100 Style Loss :  inf Content Loss: 41.609879
# 8150 Style Loss :  inf Content Loss: 41.609879
# 8200 Style Loss :  inf Content Loss: 41.609879
# 8250 Style Loss :  inf Content Loss: 41.609879
# 8300 Style Loss :  inf Content Loss: 41.609879
# 8350 Style Loss :  inf Content Loss: 41.609879
# 8400 Style Loss :  inf Content Loss: 41.609879
# 8450 Style Loss :  inf Content Loss: 41.609879
# 8500 Style Loss :  inf Content Loss: 41.609879
# 8550 Style Loss :  inf Content Loss: 41.609879
# 8600 Style Loss :  inf Content Loss: 41.609879
# 8650 Style Loss :  inf Content Loss: 41.609879
# 8700 Style Loss :  inf Content Loss: 41.609879
# 8750 Style Loss :  inf Content Loss: 41.609879
# 8800 Style Loss :  inf Content Loss: 41.609879
# 8850 Style Loss :  inf Content Loss: 41.609879
# 8900 Style Loss :  inf Content Loss: 41.609879
# 8950 Style Loss :  inf Content Loss: 41.609879
# 9000 Style Loss :  inf Content Loss: 41.609879
# 9050 Style Loss :  inf Content Loss: 41.609879
# 9100 Style Loss :  inf Content Loss: 41.609879
# 9150 Style Loss :  inf Content Loss: 41.609879
# 9200 Style Loss :  inf Content Loss: 41.609879
# 9250 Style Loss :  inf Content Loss: 41.609879
# 9300 Style Loss :  inf Content Loss: 41.609879
# 9350 Style Loss :  inf Content Loss: 41.609879
# 9400 Style Loss :  inf Content Loss: 41.609879
# 9450 Style Loss :  inf Content Loss: 41.609879
# 9500 Style Loss :  inf Content Loss: 41.609879
# 9550 Style Loss :  inf Content Loss: 41.609879
# 9600 Style Loss :  inf Content Loss: 41.609879
# 9650 Style Loss :  inf Content Loss: 41.609879
# 9700 Style Loss :  inf Content Loss: 41.609879
# 9750 Style Loss :  inf Content Loss: 41.609879
# 9800 Style Loss :  inf Content Loss: 41.609879
# 9850 Style Loss :  inf Content Loss: 41.609879
# 9900 Style Loss :  inf Content Loss: 41.609879
# 9950 Style Loss :  inf Content Loss: 41.609879
# 10000 Style Loss :  inf Content Loss: 41.609879
